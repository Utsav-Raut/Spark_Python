# %%
import findspark
findspark.init()
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.master('local[*]').appName('Prac-1').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.1.104:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Prac-1</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
spark.sparkContext.uiWebUrl
# Out:
# 'http://192.168.1.104:4040'

# %%
file_path = 'file:///home/boom/Documents/programming/python/pandas/data/survey_results_public.csv'
file_path2 = 'file:///home/boom/Documents/programming/python/pandas/data/survey_results_schema.csv'

# %%
result_df = spark.read.format('csv').option("header", True).option(delimiter=',').load(file_path)

# %%
result_df.show()
# Out:
# +----------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+--------------+--------------------+--------------------+--------------------+--------------------+--------------------+---------+----------+----------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------------+--------------------+--------+--------------------+--------------------+--------------+--------------------+---------+--------+-------------+-----------+--------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------+--------------------+----------------------+------
# ...
